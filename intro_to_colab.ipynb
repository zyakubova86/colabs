# %% [markdown]
# <a href="https://colab.research.google.com/github/zyakubova86/colabs/blob/main/intro_to_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import keras
import tensorflow
import cv2
import matplotlib.pyplot as plt

print(cv2.__version__)
print(keras.__version__)
# Out:
# 4.8.0
# 2.15.0

# %%
# !pip install opencv-contrib-python

# %%
# %%bash
# apt-get install caffe-cuda
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# E: Unable to locate package caffe-cuda
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-11-4443e4edeaae> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'sudo apt-get install caffe-cuda\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
# ...

# %%
# %%bash
# sudo ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
#
# pip install gputil
# pip install psutil
# pip install humanize
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7394 sha256=f46e76a5c49fc590f3134ad23b32625fe199993e46e30840c884bd28b9f34173
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
# Successfully built gputil
# ...

# %%
import psutil
import humanize
import os
import GPUtil as GPU

# %%
gpus = GPU.getGPUs()
gpu = gpus[0]

print(len(gpus))
# Out:
# 1

# %%
# !nvidia-smi
# Out:
# Tue Jul 23 11:58:04 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
print("""GPU RAM FREE: {0:.0f}MB | Used: {1:.0f}MB | Util: {2:.0f}% | Total: {3:.0f}MB"""
.format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
# Out:
# GPU RAM FREE: 15101MB | Used: 0MB | Util: 0% | Total: 15360MB

# %%
print(f"RAM FREE: {humanize.naturalsize( psutil.virtual_memory().available )}")
print(f"RAM TOTAL: {humanize.naturalsize( psutil.virtual_memory().total )}")
# Out:
# RAM FREE: 12.0 GB
# RAM TOTAL: 13.6 GB

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          79G   28G   51G  35% /
# tmpfs            64M     0   64M   0% /dev
# shm             5.7G     0  5.7G   0% /dev/shm
# /dev/root       2.0G  1.2G  820M  59% /usr/sbin/docker-init
# tmpfs           6.4G  8.2M  6.4G   1% /var/colab
# /dev/sda1       106G   82G   24G  78% /kaggle/input
# tmpfs           6.4G     0  6.4G   0% /proc/acpi
# tmpfs           6.4G     0  6.4G   0% /proc/scsi
# tmpfs           6.4G     0  6.4G   0% /sys/firmware

# %%
# !lsof
# Out:
# COMMAND     PID   TID TASKCMD   USER   FD      TYPE             DEVICE SIZE/OFF    NODE NAME
# docker-in     1                 root  cwd       DIR               0,54     4096 1835098 /
# docker-in     1                 root  rtd       DIR               0,54     4096 1835098 /
# docker-in     1                 root  txt       REG              253,0   765792    9190 /usr/sbin/docker-init
# docker-in     1                 root    0u      CHR                1,3      0t0       5 /dev/null
# docker-in     1                 root    1w     FIFO               0,13      0t0   18583 pipe
# docker-in     1                 root    2w     FIFO               0,13      0t0   18584 pipe
# node          7                 root  cwd       DIR               0,54     4096 1835098 /
# node          7                 root  rtd       DIR               0,54     4096 1835098 /
# node          7                 root  txt       REG               0,54 82609040 1450012 /tools/node/bin/node
# ...
